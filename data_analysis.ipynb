# %%
import json
import random
import torch
import torchtext
import tqdm

# %%
# load the json file
with open('data/sarcasm.json', 'r') as f:
    file = json.load(f)
file

# %%
print(type(file))
print(len(file))
print(file[0].keys())

rand_ind = random.randint(0, len(file))

label_mapping = {0: 'non-sarcastic',
                 1: 'sarcastic'}
# print first example
print(f'\nRunning {rand_ind} example in the datatset')
print(f'The headline: {file[rand_ind]["headline"]}')
print(f'The label of fist example: {label_mapping[file[rand_ind]["is_sarcastic"]]}')
print(f'article link: {file[rand_ind]["article_link"]}')
# Out:
# <class 'list'>
# 26709
# dict_keys(['article_link', 'headline', 'is_sarcastic'])
#
# Running 1135 example in the datatset
# The headline: things come apart so easily: asghar farhadi's about elly
# The label of fist example: non-sarcastic
# article link: https://www.huffingtonpost.com/entry/things-come-apart-so-easi_b_7023922.html

# %%
# randomize the contents in teh list
random.shuffle(file)

# %%
# split the dataset into to parts i.e. test and train
train_length = int(len(file) * 0.8)
training_examples = file[:train_length]
testing_examples = file[train_length:]

# %%
class sarcasticDataset(torch.utils.data.Dataset):
    def __init__(self, dataset):
        self.dataset = dataset

    def __len__(self):
        return len(self.dataset)
    
    def map(self, tokenization_function, fn_kwargs = {}):
        # Apply the provided tokenization function to each example in the dataset
        tokenized_data = [tokenization_function(example, **fn_kwargs) for example in self.dataset]
        return tokenized_data
    
    def __getitem__(self, indx):  
        if indx in range(0, len(self.dataset)):
            sample = self.dataset[indx]
            headline = sample["headline"]
            label = sample["is_sarcastic"]
            return (headline, label)
        else:
            raise  ValueError(f"index {indx} is not in the range [{0}, {len(self.dataset)}]")

# %%
test_data = sarcasticDataset(testing_examples)
train_data = sarcasticDataset(training_examples)

# %%
test_loader = torch.utils.data.DataLoader(test_data, batch_size= 4, shuffle= False, 
                                     pin_memory = True, drop_last = True)


train_loader = torch.utils.data.DataLoader(train_data, batch_size= 4, shuffle= True, 
                                     pin_memory = True, drop_last = True)

# %%
print(len(train_loader))
print(len(test_loader))
# Out:
# 5341
# 1335

# %%
headlines,labels = next(iter(test_loader))

# %%
headlines, labels
# Out:
# (("why south sudan's leaders are fueling the implosion of their own country",
#   'bernie sanders just tweeted the most evergreen response to cbo score',
#   'drug addict looking for more enabling girlfriend',
#   'spanish government threatens to impose direct rule in catalonia'),
#  tensor([0, 0, 1, 0]))

# %%
# Next Step: convert the text to the numerical representation 

seed = 0

torch.manual_seed(seed)

# %%
tokenizer = torchtext.data.utils.get_tokenizer('basic_english')

# %%
def tokenize_data(example, tokenizer, max_length):
    tokens = tokenizer(example['headline'])[:max_length]
    label = example["is_sarcastic"]
    length = len(tokens)
    return {'tokens': tokens, 'label': label, 'length': length}

# %%
# tokenization illustration
max_length = 256
example = file[0]
print(f'original text: {file[0]["headline"]}')
output = tokenize_data(example, tokenizer, max_length)
print(output)
# Out:
# original text: 10 eating habits linked to dying from cardiovascular disease and diabetes
# {'tokens': ['10', 'eating', 'habits', 'linked', 'to', 'dying', 'from', 'cardiovascular', 'disease', 'and', 'diabetes'], 'label': 0, 'length': 11}

# %%
train_data = train_data.map(tokenize_data, fn_kwargs={'tokenizer': tokenizer, 'max_length': max_length})
test_data = test_data.map(tokenize_data, fn_kwargs={'tokenizer': tokenizer, 'max_length': max_length})

# %%
test_loader = torch.utils.data.DataLoader(test_data, batch_size= 4, shuffle= False, 
                                     pin_memory = True, drop_last = True)


train_loader = torch.utils.data.DataLoader(train_data, batch_size= 4, shuffle= True, 
                                     pin_memory = True, drop_last = True)

# %%
output = next(iter(test_loader))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# e:\DL_mini_projects\sentiment_text_generation\sentiment_analysis_and_text_generation\data_analysis.ipynb Cell 18 line 1
# ----> <a href='vscode-notebook-cell:/e%3A/DL_mini_projects/sentiment_text_generation/sentiment_analysis_and_text_generation/data_analysis.ipynb#X23sZmlsZQ%3D%3D?line=0'>1</a> output = next(iter(test_loader))
#
# File c:\Users\faizan\anaconda3\envs\dl_task3\lib\site-packages\torch\utils\data\dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File c:\Users\faizan\anaconda3\envs\dl_task3\lib\site-packages\torch\utils\data\dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File c:\Users\faizan\anaconda3\envs\dl_task3\lib\site-packages\torch\utils\data\_utils\fetch.py:54, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
# ---> 54 return self.collate_fn(data)
#
# File c:\Users\faizan\anaconda3\envs\dl_task3\lib\site-packages\torch\utils\data\_utils\collate.py:265, in default_collate(batch)
#     204 def default_collate(batch):
#     205     r"""
#     206         Function that takes in a batch of data and puts the elements within the batch
#     207         into a tensor with an additional outer dimension - batch size. The exact output type can be
#    (...)
#     263             >>> default_collate(batch)  # Handle `CustomType` automatically
#     264     """
# --> 265     return collate(batch, collate_fn_map=default_collate_fn_map)
#
# File c:\Users\faizan\anaconda3\envs\dl_task3\lib\site-packages\torch\utils\data\_utils\collate.py:127, in collate(batch, collate_fn_map)
#     125 if isinstance(elem, collections.abc.Mapping):
#     126     try:
# --> 127         return elem_type({key: collate([d[key] for d in batch], collate_fn_map=collate_fn_map) for key in elem})
#     128     except TypeError:
#     129         # The mapping type may not support `__init__(iterable)`.
#     130         return {key: collate([d[key] for d in batch], collate_fn_map=collate_fn_map) for key in elem}
#
# File c:\Users\faizan\anaconda3\envs\dl_task3\lib\site-packages\torch\utils\data\_utils\collate.py:127, in <dictcomp>(.0)
#     125 if isinstance(elem, collections.abc.Mapping):
#     126     try:
# --> 127         return elem_type({key: collate([d[key] for d in batch], collate_fn_map=collate_fn_map) for key in elem})
#     128     except TypeError:
#     129         # The mapping type may not support `__init__(iterable)`.
#     130         return {key: collate([d[key] for d in batch], collate_fn_map=collate_fn_map) for key in elem}
#
# File c:\Users\faizan\anaconda3\envs\dl_task3\lib\site-packages\torch\utils\data\_utils\collate.py:138, in collate(batch, collate_fn_map)
#     136 elem_size = len(next(it))
#     137 if not all(len(elem) == elem_size for elem in it):
# --> 138     raise RuntimeError('each element in list of batch should be of equal size')
#     139 transposed = list(zip(*batch))  # It may be accessed twice, so we use a list.
#     141 if isinstance(elem, tuple):
#
# RuntimeError: each element in list of batch should be of equal size

# %%
test_data
# Out:
# [{'tokens': ['why',
#    'south',
#    'sudan',
#    "'",
#    's',
#    'leaders',
#    'are',
#    'fueling',
#    'the',
#    'implosion',
#    'of',
#    'their',
#    'own',
#    'country'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['bernie',
#    'sanders',
#    'just',
#    'tweeted',
#    'the',
#    'most',
#    'evergreen',
#    'response',
#    'to',
#    'cbo',
#    'score'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['drug',
#    'addict',
#    'looking',
#    'for',
#    'more',
#    'enabling',
#    'girlfriend'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['spanish',
#    'government',
#    'threatens',
#    'to',
#    'impose',
#    'direct',
#    'rule',
#    'in',
#    'catalonia'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['sea',
#    'lion',
#    'yanks',
#    'man',
#    'off',
#    'boat',
#    'in',
#    'effort',
#    'to',
#    'snatch',
#    'fish'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['report',
#    'getting',
#    'out',
#    'of',
#    'bed',
#    'in',
#    'morning',
#    'sharply',
#    'increases',
#    'risk',
#    'of',
#    'things',
#    'getting',
#    'even',
#    'worse'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['local', 'dad', 'gets', 'this', 'show', 'on', 'the', 'road'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['the',
#    'secrets',
#    'behind',
#    'the',
#    'alvin',
#    'ailey',
#    'american',
#    'dance',
#    'theater'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['a',
#    'tribute',
#    'to',
#    'alan',
#    'rickman',
#    'reading',
#    'between',
#    'the',
#    'black',
#    'and',
#    'white'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['man', 'sneaks', 'in', 'mid-snack', 'nibble'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['trump',
#    "'",
#    's',
#    'revised',
#    'travel',
#    'ban',
#    'is',
#    'still',
#    'mired',
#    'in',
#    'prejudice'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['we',
#    "'",
#    've',
#    'seen',
#    'the',
#    'future',
#    'of',
#    'flight',
#    ',',
#    'and',
#    'it',
#    "'",
#    's',
#    'awesome'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['lisa',
#    'kudrow',
#    ',',
#    'craig',
#    'robinson',
#    'and',
#    'wyatt',
#    'russell',
#    'answer',
#    'your',
#    'wedding',
#    'etiquette',
#    'questions'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['trump', 'pardons', '?'], 'label': 0, 'length': 3},
#  {'tokens': ['chelsea',
#    'clinton',
#    'calls',
#    'to',
#    'stop',
#    'the',
#    'demand',
#    'for',
#    'ivory',
#    'to',
#    'protect',
#    'africa',
#    "'",
#    's',
#    'elephants'],
#   'label': 0,
#   'length': 15},
#  {'tokens': ['belgrade',
#    "'",
#    's',
#    '4th',
#    'non-violent',
#    'pride',
#    'pics',
#    'show',
#    'a',
#    'bubble',
#    'of',
#    'freedom',
#    'for',
#    'lgbtq',
#    'people',
#    'in',
#    'serbia'],
#   'label': 0,
#   'length': 17},
#  {'tokens': ['weekly', 'roundup', 'of', 'ebay', 'vintage', 'home', 'finds'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['lamar',
#    'odom',
#    'leaves',
#    'hospital',
#    'after',
#    "'",
#    'miraculous',
#    'and',
#    'continued',
#    'improvement',
#    "'"],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['pot',
#    'products',
#    'are',
#    'now',
#    'so',
#    'potent',
#    'they',
#    'can',
#    'trigger',
#    'psychosis'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['anne',
#    'frank',
#    'center',
#    'blasts',
#    'trump',
#    "'",
#    's',
#    'limp',
#    'anti-semitism',
#    'response'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['russian',
#    'interference',
#    'had',
#    'no',
#    'impact',
#    'on',
#    'election',
#    ',',
#    'reports',
#    'website',
#    'created',
#    '8',
#    'minutes',
#    'ago'],
#   'label': 1,
#   'length': 14},
#  {'tokens': ['dad',
#    'tests',
#    'limits',
#    'of',
#    'cheesecake',
#    'factory',
#    'vibrating',
#    'pager'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['i',
#    "'",
#    'm',
#    'really',
#    'upset',
#    'about',
#    'the',
#    'midterm',
#    'elections',
#    'god',
#    'i',
#    'love',
#    'my',
#    'new',
#    'iphone'],
#   'label': 0,
#   'length': 15},
#  {'tokens': ['group',
#    'files',
#    'complaint',
#    'against',
#    'judge',
#    'who',
#    'sentenced',
#    'man',
#    'to',
#    'marry',
#    'girlfriend'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['god',
#    'rewinds',
#    'time',
#    'to',
#    'watch',
#    'man',
#    'fall',
#    'off',
#    'trampoline',
#    'again'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['man',
#    'worried',
#    'about',
#    'drug',
#    'dealer',
#    'who',
#    "'",
#    's',
#    'not',
#    'picking',
#    'up',
#    'phone'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['how',
#    'climate',
#    'change',
#    'is',
#    'fueling',
#    'violence',
#    'against',
#    'women'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['f',
#    '.',
#    'a',
#    '.',
#    's',
#    '.',
#    't',
#    '.',
#    'thinking',
#    'helped',
#    'lane',
#    'save',
#    'his',
#    'mom'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['this',
#    'election',
#    'decides',
#    'our',
#    'future',
#    'for',
#    'a',
#    'generation'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['famed', 'chef', 'homaro', 'cantu', 'found', 'dead'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['this',
#    'is',
#    'a',
#    'middle-aged',
#    'man',
#    "'",
#    's',
#    'true',
#    'path',
#    'to',
#    'happiness'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['scientists',
#    'receive',
#    '$10',
#    'million',
#    'grant',
#    'to',
#    'melt',
#    'stuff'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['entitled',
#    'deadbeat',
#    'finally',
#    'breaks',
#    'out',
#    'of',
#    '20-year',
#    'cycle',
#    'of',
#    'government',
#    'dependency'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['end',
#    'the',
#    'international',
#    'drug',
#    'war',
#    'to',
#    'control',
#    'the',
#    'afghan',
#    'narco-state'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['orrin',
#    'hatch',
#    'mistakenly',
#    'left',
#    'dangling',
#    'in',
#    'bondage-fetish',
#    'dungeon'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['al',
#    'roker',
#    'slams',
#    "'",
#    'moron',
#    "'",
#    'jim',
#    'inhofe',
#    'for',
#    'bringing',
#    'snowball',
#    'to',
#    'senate'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['changing', 'the', 'playlist', 'in', 'my', 'head'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['obama',
#    'throws',
#    'up',
#    'right',
#    'there',
#    'during',
#    'syria',
#    'meeting'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['isis', 'and', 'the', 'g-41', 'world'], 'label': 0, 'length': 5},
#  {'tokens': ['detective',
#    'not',
#    'sure',
#    'he',
#    'was',
#    'close',
#    'enough',
#    'to',
#    'partner',
#    'to',
#    'endlessly',
#    'pursue',
#    'killer'],
#   'label': 1,
#   'length': 13},
#  {'tokens': ['david',
#    'koch',
#    'delivers',
#    'suit',
#    'with',
#    'note',
#    'reading',
#    "'",
#    'wear',
#    'this',
#    'tonight',
#    "'",
#    'to',
#    'marco',
#    'rubio',
#    "'",
#    's',
#    'hotel',
#    'room'],
#   'label': 1,
#   'length': 19},
#  {'tokens': ['nasa',
#    'designers',
#    'release',
#    'flirty',
#    'new',
#    'space',
#    'skirt'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['death',
#    'toll',
#    'from',
#    'california',
#    'mudslides',
#    'rises',
#    'to',
#    '21',
#    'after',
#    'mom',
#    "'",
#    's',
#    'body',
#    'found'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ["'",
#    'f**k',
#    'muzlim',
#    "'",
#    'and',
#    "'",
#    'terroist',
#    "'",
#    'spray-painted',
#    'on',
#    'muslim',
#    'man',
#    "'",
#    's',
#    'car'],
#   'label': 0,
#   'length': 15},
#  {'tokens': ['nordstrom',
#    'just',
#    'low-key',
#    'dropped',
#    'a',
#    'huge',
#    'fall',
#    'sale'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['australian',
#    'asylum',
#    'seekers',
#    'told',
#    'to',
#    'choose',
#    'life',
#    'in',
#    'jail',
#    'or',
#    'risk',
#    'death',
#    'in',
#    'home',
#    'countries'],
#   'label': 0,
#   'length': 15},
#  {'tokens': ['pele', 'hospitalized', 'for', 'back', 'surgery'],
#   'label': 0,
#   'length': 5},
#  {'tokens': ['intelligence',
#    'officials',
#    'can',
#    "'",
#    't',
#    'say',
#    'how',
#    'many',
#    'americans',
#    'they',
#    'spy',
#    'on'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['when',
#    'we',
#    'celebrate',
#    'our',
#    'differences',
#    ',',
#    'we',
#    'make',
#    'a',
#    'better',
#    'world',
#    'for',
#    'all'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['read', 'live', 'updates', 'on', 'the', 'government', 'shutdown'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['how',
#    'brazil',
#    "'",
#    's',
#    "'",
#    'lord',
#    'of',
#    'guns',
#    "'",
#    'armed',
#    'rio',
#    "'",
#    's',
#    'drug',
#    'war',
#    'with',
#    'u',
#    '.',
#    's',
#    '.',
#    'weapons'],
#   'label': 0,
#   'length': 21},
#  {'tokens': ['the',
#    'hollywood',
#    'boys',
#    "'",
#    'club',
#    'that',
#    'supports',
#    'casey',
#    'affleck',
#    'is',
#    'a',
#    'total',
#    'disgrace'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['our', 'american', 'life'], 'label': 0, 'length': 3},
#  {'tokens': ['a',
#    'brief',
#    'history',
#    'of',
#    'paul',
#    'ryan',
#    "'",
#    's',
#    'dance',
#    'of',
#    'death',
#    'with',
#    'donald',
#    'trump'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['purritos',
#    '=',
#    'cats',
#    ',',
#    'burritos',
#    ',',
#    'the',
#    'internet',
#    '.',
#    'all',
#    'our',
#    'favorite',
#    'things'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['pink',
#    'gets',
#    'real',
#    'about',
#    'the',
#    "'",
#    'most',
#    'humbling',
#    "'",
#    'part',
#    'of',
#    'parenting'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['latinx',
#    'artists',
#    'are',
#    'using',
#    'this',
#    'hashtag',
#    'to',
#    'showcase',
#    'their',
#    'incredible',
#    'talent'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['craig',
#    'sager',
#    'brings',
#    'his',
#    'a-game',
#    'to',
#    'facetime',
#    'fellow',
#    'cancer',
#    'patient'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['u',
#    '.',
#    'n',
#    '.',
#    'aid',
#    'workers',
#    'distributing',
#    'food',
#    'to',
#    'malnourished',
#    'kfc',
#    'customers'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['coffman',
#    'says',
#    'tancredo',
#    'is',
#    "'",
#    'bored',
#    "'",
#    'and',
#    'angry'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['spotify',
#    'hit',
#    'with',
#    '$1',
#    '.',
#    '6',
#    'billion',
#    'lawsuit',
#    'from',
#    'publisher',
#    'representing',
#    'tom',
#    'petty',
#    ',',
#    'neil',
#    'young'],
#   'label': 0,
#   'length': 16},
#  {'tokens': ['the',
#    'rnc',
#    'asked',
#    'tweeters',
#    'to',
#    'take',
#    'a',
#    'donald',
#    'trump',
#    'approval',
#    'poll',
#    '.',
#    'they',
#    'did',
#    'so',
#    'with',
#    'glee',
#    '.'],
#   'label': 0,
#   'length': 18},
#  {'tokens': ['here',
#    'is',
#    'what',
#    'no',
#    'one',
#    'says',
#    'out',
#    'loud',
#    'about',
#    'raising',
#    'a',
#    '13-year-old',
#    'son',
#    'with',
#    'autism'],
#   'label': 0,
#   'length': 15},
#  {'tokens': ['unbelted',
#    'rider',
#    'in',
#    'the',
#    'back',
#    'could',
#    'kill',
#    'someone',
#    'in',
#    'the',
#    'front'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['dog',
#    'the',
#    'bounty',
#    'hunter',
#    'joins',
#    'lawsuit',
#    'against',
#    'chris',
#    'christie',
#    'over',
#    'bail',
#    'reform'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['mike', 'boggs', "'", 'record', 'catches', 'up', 'to', 'him'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['amy',
#    'schumer',
#    'denies',
#    'she',
#    'has',
#    'a',
#    "'",
#    'blind',
#    'spot',
#    "'",
#    'about',
#    'race'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['fox',
#    'producers',
#    'attempt',
#    'to',
#    'tire',
#    'out',
#    'aggressive',
#    'candidates',
#    'before',
#    'debate',
#    'by',
#    'letting',
#    'them',
#    'run',
#    'around',
#    'outside'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['a-sides',
#    'with',
#    'jon',
#    'chattman',
#    'ryan',
#    'shaw',
#    'shows',
#    'some',
#    'real',
#    'love',
#    'animal',
#    'years',
#    'lift',
#    'some',
#    'spirits'],
#   'label': 0,
#   'length': 15},
#  {'tokens': ['ap',
#    'reporter',
#    'in',
#    'gaza',
#    'needs',
#    'another',
#    'term',
#    'for',
#    "'",
#    'blood-soaked',
#    "'"],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['sorry',
#    'gop',
#    ',',
#    'mike',
#    'pence',
#    'can',
#    "'",
#    't',
#    'save',
#    'you',
#    'from',
#    'donald',
#    'trump'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['catholic',
#    'child',
#    'told',
#    'about',
#    'doggy',
#    'heaven',
#    ',',
#    'doggy',
#    'hell'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['mike',
#    'pence',
#    'vows',
#    'to',
#    'cut',
#    'conservation',
#    'funding',
#    'after',
#    'discovering',
#    'elk',
#    'don',
#    "'",
#    't',
#    'mate',
#    'for',
#    'life'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['husky',
#    'can',
#    "'",
#    't',
#    'stop',
#    'blowing',
#    'bubbles',
#    'we',
#    'can',
#    "'",
#    't',
#    'stop',
#    'saying',
#    'awww'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ["'",
#    'the',
#    'wire',
#    "'",
#    'cast',
#    'reunited',
#    'in',
#    'baltimore',
#    'to',
#    'uplift',
#    'community'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['childish',
#    'gambino',
#    'releases',
#    'new',
#    'song',
#    "'",
#    'candler',
#    'road',
#    "'"],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['east',
#    'st',
#    '.',
#    'louis',
#    'rated',
#    "'",
#    'number',
#    'one',
#    'city',
#    'in',
#    'america',
#    "'",
#    'by',
#    'poverty',
#    'magazine'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['perfect', 'girlfriend', 'blames', 'self', 'for', 'everything'],
#   'label': 1,
#   'length': 6},
#  {'tokens': ['huffpost',
#    'rise',
#    'what',
#    'you',
#    'need',
#    'to',
#    'know',
#    'on',
#    'february',
#    '8'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['mcdonald',
#    "'",
#    's',
#    'birthday',
#    'party',
#    'to',
#    'be',
#    'happiest',
#    'time',
#    'in',
#    'child',
#    "'",
#    's',
#    'life'],
#   'label': 1,
#   'length': 14},
#  {'tokens': ['televised',
#    'sporting',
#    'event',
#    'completely',
#    'obscured',
#    'by',
#    'on-screen',
#    'graphics'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['10',
#    'lessons',
#    'we',
#    'learned',
#    'from',
#    'diane',
#    'keaton',
#    "'",
#    's',
#    'new',
#    'book'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['hero',
#    'soldier',
#    'receives',
#    'presidential',
#    'thumbs-up',
#    'award'],
#   'label': 1,
#   'length': 6},
#  {'tokens': ['dorito-factory',
#    'employee',
#    'can',
#    "'",
#    't',
#    'get',
#    'cool-ranch',
#    'smell',
#    'out',
#    'of',
#    'clothes'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['milkshake', 'almost', 'ruined', 'by', 'breakup'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['why',
#    'russell',
#    'simmons',
#    'wants',
#    'trump',
#    'to',
#    'win',
#    'the',
#    'gop',
#    'nomination'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['white',
#    'house',
#    'official',
#    'reportedly',
#    'said',
#    'mass',
#    'shooting',
#    'was',
#    'a',
#    "'",
#    'reprieve',
#    "'",
#    'from',
#    'chaos'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['obama',
#    'sort',
#    'of',
#    'freaked',
#    'out',
#    'after',
#    'not',
#    'receiving',
#    'single',
#    'e-mail',
#    ',',
#    'phone',
#    'call',
#    'for',
#    'entire',
#    'day'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['trump',
#    'praises',
#    'saddam',
#    'hussein',
#    'again',
#    '—',
#    'this',
#    'time',
#    'for',
#    'killing',
#    'terrorists',
#    "'",
#    'so',
#    'good',
#    "'"],
#   'label': 0,
#   'length': 15},
#  {'tokens': ['my',
#    'niece',
#    'has',
#    'cancer',
#    'and',
#    'i',
#    "'",
#    'm',
#    'ticked',
#    'about',
#    'it'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['what',
#    "'",
#    's',
#    'for',
#    'breakfast',
#    '?',
#    'how',
#    'about',
#    'some',
#    'monsanto',
#    'weed',
#    'killer',
#    '?'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['suicide',
#    'bombing',
#    'near',
#    'afghan',
#    'parliament',
#    'kills',
#    'more',
#    'than',
#    '30'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['friends',
#    'and',
#    'family',
#    'rally',
#    'around',
#    'kim',
#    'kardashian',
#    'on',
#    'her',
#    'birthday'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['nick',
#    'verreos',
#    'sees',
#    'a',
#    'marriage',
#    'between',
#    'fashion',
#    'geeks',
#    'and',
#    'computer',
#    'geeks'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['kendall',
#    'and',
#    'kylie',
#    'jenner',
#    'get',
#    'revenge',
#    'on',
#    'cheating',
#    'guy',
#    'in',
#    'snapchat',
#    'soap',
#    'opera'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['pregnant',
#    'kim',
#    'kardashian',
#    'and',
#    'kylie',
#    'jenner',
#    'rock',
#    'sister',
#    'crop',
#    'tops'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['pentagon', 'ripped', 'off', 'by', 'shady', 'weapons', 'dealer'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['local', 'couple', 'needs', 'to', 'talk'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['meatless',
#    'monday',
#    'the',
#    'seed',
#    'of',
#    'something',
#    'great',
#    '--',
#    'seed',
#    'food',
#    'and',
#    'wine',
#    'festival'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['women',
#    'in',
#    'business',
#    'carolina',
#    'toro-gerstein',
#    ',',
#    'ceo',
#    'and',
#    'founder',
#    'of',
#    'poncho',
#    'baby',
#    'inc'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['we',
#    'learn',
#    'our',
#    'best',
#    'lessons',
#    'when',
#    'we',
#    'fail',
#    ',',
#    'according',
#    'to',
#    'pete',
#    'carroll'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['documentary',
#    'review',
#    '3',
#    '1/2',
#    'minutes',
#    ',',
#    'ten',
#    'bullets'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['tsa',
#    'agents',
#    'to',
#    'now',
#    'simply',
#    'stand',
#    'at',
#    'checkpoints',
#    'and',
#    'remind',
#    'passengers',
#    'that',
#    'we',
#    'all',
#    'die',
#    'someday'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['delta',
#    'pilot',
#    'refuses',
#    'to',
#    'land',
#    'until',
#    'gun',
#    'control',
#    'legislation',
#    'passed'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['another', 'times', 'square', "'", 'spider-man', "'", 'arrested'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['the',
#    '10',
#    'best',
#    'cities',
#    'for',
#    'college',
#    'grads',
#    'in',
#    '2015'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['alec', 'baldwin', 'secretes', 'own', 'hair', 'gel'],
#   'label': 1,
#   'length': 6},
#  {'tokens': ['heavily',
#    'starched',
#    'shirt',
#    'only',
#    'thing',
#    'keeping',
#    'larry',
#    'king',
#    'upright'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['freak', 'accident', 'paralyzes', 'man', 'from', 'waist', 'up'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['what',
#    "'",
#    's',
#    'really',
#    'lurking',
#    'in',
#    'those',
#    'pedicure',
#    'tubs',
#    '?'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['3-day', 'weekend', 'practically', 'already', 'over'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['microwave-popcorn',
#    'bag',
#    'a',
#    'maze',
#    'of',
#    'arrows',
#    'and',
#    'instructions'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['robin',
#    'williams',
#    'body-hair-mowing',
#    'project',
#    'enters',
#    'third',
#    'week'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['federal',
#    'judge',
#    'refuses',
#    'to',
#    'block',
#    'mississippi',
#    'anti-lgbt',
#    'law'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['sunday',
#    'show',
#    'hosts',
#    'hit',
#    'back',
#    'on',
#    'trump',
#    'administration',
#    "'",
#    's',
#    'lies'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['nation',
#    "'",
#    's',
#    'poor',
#    'bastards',
#    'never',
#    'even',
#    'saw',
#    'it',
#    'coming'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['hilary',
#    'duff',
#    "'",
#    's',
#    'heartbreaking',
#    'instagram',
#    'shows',
#    'how',
#    'hard',
#    'it',
#    'is',
#    'to',
#    'lose',
#    'a',
#    'pet'],
#   'label': 0,
#   'length': 15},
#  {'tokens': ['tim',
#    'kaine',
#    'forced',
#    'to',
#    'drink',
#    'ipecac',
#    'after',
#    'eating',
#    'sheet',
#    'of',
#    "'",
#    'i',
#    "'",
#    'm',
#    'with',
#    'her',
#    "'",
#    'stickers'],
#   'label': 1,
#   'length': 18},
#  {'tokens': ['storied',
#    'fantasy',
#    'owner',
#    'relocates',
#    'to',
#    'new',
#    'ip',
#    'address'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['john',
#    'travolta',
#    'is',
#    'very',
#    'thankful',
#    'for',
#    "'",
#    'dick',
#    'poop',
#    "'"],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['gears',
#    'of',
#    'war',
#    'crimes',
#    'court',
#    'finds',
#    '2006',
#    'locust',
#    'horde',
#    'massacre',
#    'justified'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['arianna',
#    'huffington',
#    'has',
#    'webcam',
#    'implanted',
#    'in',
#    'forehead'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['poll',
#    'finds',
#    'only',
#    '83%',
#    'of',
#    'new',
#    'yorkers',
#    'visit',
#    'statue',
#    'of',
#    'liberty',
#    'every',
#    'day'],
#   'label': 1,
#   'length': 13},
#  {'tokens': ['nervous',
#    'pope',
#    'candidate',
#    'changes',
#    'wine',
#    'into',
#    'jesus',
#    'christ',
#    "'",
#    's',
#    'urine'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['stormy',
#    'daniels',
#    "'",
#    '60',
#    'minutes',
#    "'",
#    'interview',
#    'leads',
#    'to',
#    'spike',
#    'in',
#    'pornhub',
#    'searches',
#    'for',
#    'anderson',
#    'cooper'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['wedding',
#    'photographer',
#    'keeps',
#    'calling',
#    'bride',
#    "'",
#    's',
#    'parents',
#    "'",
#    'mom',
#    "'",
#    'and',
#    "'",
#    'dad',
#    "'"],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['palestinians',
#    'suspicious',
#    'of',
#    'al-aqsa',
#    'surveillance',
#    'promoted',
#    'by',
#    'kerry'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['what', 'refugees', 'really', 'want'], 'label': 0, 'length': 4},
#  {'tokens': ['security',
#    'guard',
#    'makes',
#    'passing',
#    'women',
#    'feel',
#    'unsafe'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['how', 'to', 'get', 'out', 'of', 'a', 'bad', 'mood'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['samantha',
#    'bee',
#    'tells',
#    'democrats',
#    'what',
#    'it',
#    "'",
#    'll',
#    'take',
#    'to',
#    'stop',
#    'donald',
#    'trump'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['garden', 'too', 'much', 'for', 'grandma', 'this', 'summer'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['republicans',
#    'vow',
#    'not',
#    'to',
#    'repeal',
#    'obamacare',
#    'without',
#    'detailed',
#    'plan',
#    'for',
#    'disposing',
#    'of',
#    'patients',
#    "'",
#    'disease-ridden',
#    'corpses'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['clinton',
#    'dragged',
#    'up',
#    'on',
#    'stage',
#    'to',
#    'sing',
#    "'",
#    'sweet',
#    'home',
#    'alabama',
#    "'",
#    'with',
#    'the',
#    'band'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['emails',
#    'how',
#    'the',
#    'obama',
#    'administration',
#    'secretly',
#    'approved',
#    'expanding',
#    'piece',
#    'of',
#    'enbridge',
#    "'",
#    's',
#    'keystone',
#    'xl',
#    'clone'],
#   'label': 0,
#   'length': 16},
#  {'tokens': ['u',
#    '.',
#    's',
#    '.',
#    'dollar',
#    'drops',
#    'against',
#    'counterfeit',
#    'u',
#    '.',
#    's',
#    '.',
#    'dollar'],
#   'label': 1,
#   'length': 13},
#  {'tokens': ['the',
#    'stop',
#    'trump',
#    'movement',
#    'got',
#    'new',
#    'life',
#    'in',
#    'ohio'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['this',
#    'teenager',
#    "'",
#    's',
#    'gory',
#    'special',
#    'effects',
#    'videos',
#    'are',
#    'bloody',
#    'impressive'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['arby',
#    "'",
#    's',
#    'ceo',
#    'arrested',
#    'with',
#    'trunk',
#    'full',
#    'of',
#    'stolen',
#    'horsey',
#    'sauce'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['winter',
#    'storm',
#    'brings',
#    'ice',
#    'and',
#    'freezing',
#    'rain',
#    'to',
#    'central',
#    'u',
#    '.',
#    's',
#    '.'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['america',
#    ',',
#    'china',
#    'trying',
#    'to',
#    'spice',
#    'up',
#    'trade',
#    'relationship',
#    'by',
#    'bringing',
#    'third',
#    'country',
#    'into',
#    'negotiations'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['how',
#    'not',
#    'to',
#    'look',
#    'like',
#    'a',
#    'tourist',
#    'in',
#    'berlin'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['an',
#    'open',
#    'letter',
#    'to',
#    'my',
#    'shelter',
#    'dog',
#    "'",
#    's',
#    'first',
#    'owner'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['5',
#    'of',
#    'the',
#    'most',
#    'interesting',
#    'restaurants',
#    'in',
#    'the',
#    'world'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['lea',
#    'delaria',
#    'can',
#    'make',
#    'you',
#    'feel',
#    'butch',
#    'without',
#    'all',
#    'of',
#    'the',
#    'hard',
#    'work'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['new',
#    'television',
#    'show',
#    'to',
#    'examine',
#    'rarely',
#    'discussed',
#    'years',
#    'between',
#    '1980',
#    'and',
#    '1989'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['moving', 'forward', 'from', 'charlottesville'],
#   'label': 0,
#   'length': 4},
#  {'tokens': ['area', 'man', 'pretty', 'loud', 'at', 'guitar'],
#   'label': 1,
#   'length': 6},
#  {'tokens': ['spring', 'on', 'spring', 'street', 'a', 'tale', 'of', 'rebirth'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['the',
#    'history',
#    'of',
#    'the',
#    'baby',
#    'name',
#    "'",
#    'stormi',
#    "'"],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['fda',
#    'questions',
#    'use',
#    'of',
#    'aspirin',
#    'to',
#    'prevent',
#    'first',
#    'heart',
#    'attack'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['texas',
#    'ebola',
#    'patient',
#    "'",
#    'fighting',
#    'for',
#    'his',
#    'life',
#    "'"],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['roommates',
#    'still',
#    'don',
#    "'",
#    't',
#    'know',
#    'each',
#    'other',
#    'well',
#    'enough',
#    'to',
#    'not',
#    'speak'],
#   'label': 1,
#   'length': 13},
#  {'tokens': ['nasim',
#    'nasr',
#    "'",
#    's',
#    'zaeefeh',
#    '(',
#    'the',
#    'wretchedness',
#    ')',
#    'and',
#    'shadi',
#    '(',
#    'happiness',
#    ')',
#    ',',
#    'gagprojects',
#    'adelaide/berlin',
#    'at',
#    'the',
#    '2015',
#    'art',
#    'dubai'],
#   'label': 0,
#   'length': 22},
#  {'tokens': ['3',
#    'things',
#    'that',
#    'young',
#    'women',
#    'need',
#    'to',
#    'remember',
#    'about',
#    'feminism'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['joint',
#    'chiefs',
#    'chairman',
#    'pretty',
#    'sure',
#    'he',
#    'could',
#    'pull',
#    'off',
#    'junta',
#    'if',
#    'he',
#    'really',
#    'wanted',
#    'to'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['a', 'taste', 'of', 'proper', 'fun', 'bermuda'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['heart-shaped', 'jacuzzi', 'clogged', 'again'],
#   'label': 1,
#   'length': 4},
#  {'tokens': ['my', 'time', 'as', 'a', 'philly', 'juror'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['marketing',
#    'department',
#    'under',
#    'impression',
#    'keebler',
#    'elves',
#    'a',
#    'beloved',
#    'part',
#    'of',
#    'american',
#    'culture'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['epa',
#    'study',
#    'rivers',
#    'shouldn',
#    "'",
#    't',
#    'smell',
#    'like',
#    'shit'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['man',
#    'in',
#    'mickey',
#    'mouse',
#    'suit',
#    'obviously',
#    'attempted',
#    'to',
#    'eat',
#    'ribs'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['the', 'prophet', 'of', 'jordan', "'", 's', 'mists'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['texas', 'attorney', 'general', 'ken', 'paxton', 'indicted'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['kentucky',
#    'clerk',
#    'asks',
#    'court',
#    'to',
#    'force',
#    'governor',
#    'to',
#    'let',
#    'her',
#    'deny',
#    'gay',
#    'marriages'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['death',
#    'penalty',
#    'and',
#    'redemption',
#    'thoughts',
#    'on',
#    'tsarnaev',
#    'and',
#    'american',
#    'christianity'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['casual', 'sex', 'surprisingly', 'formal'],
#   'label': 1,
#   'length': 4},
#  {'tokens': ['bank',
#    'of',
#    'america',
#    'touts',
#    'going',
#    'green',
#    'but',
#    'funnels',
#    'billions',
#    'into',
#    'fossil',
#    'fuels'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['advice', 'for', 'the', 'broken-hearted'],
#   'label': 0,
#   'length': 4},
#  {'tokens': ['donald',
#    'trump',
#    'jr',
#    '.',
#    "'",
#    's',
#    'rnc',
#    'speech',
#    'uses',
#    'lines',
#    'from',
#    'conservative',
#    'columnist'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['transgender',
#    'people',
#    'open',
#    'up',
#    'about',
#    'the',
#    'impact',
#    'of',
#    'hiv',
#    'on',
#    'the',
#    'trans',
#    'community'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['nation',
#    'not',
#    'sure',
#    'how',
#    'many',
#    'ex-trump',
#    'staffers',
#    'it',
#    'can',
#    'safely',
#    'reabsorb'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['7',
#    'genius',
#    'napping',
#    'inventions',
#    'to',
#    'get',
#    'you',
#    'through',
#    'monday'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['don',
#    "'",
#    't',
#    'passively',
#    'online',
#    'shame',
#    'hurricane',
#    'irma',
#    'residents'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['pudgy',
#    'doughboy',
#    'with',
#    'rosy',
#    'red',
#    'cheeks',
#    'presses',
#    'nose',
#    'up',
#    'against',
#    'window',
#    'of',
#    'chocolate',
#    'shop'],
#   'label': 1,
#   'length': 14},
#  {'tokens': ['astronomers',
#    'discover',
#    'previously',
#    'unknown',
#    'cluster',
#    'of',
#    'nothingness',
#    'in',
#    'deep',
#    'space'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['father',
#    'only',
#    'expresses',
#    'love',
#    'through',
#    'concern',
#    'for',
#    'proper',
#    'tire',
#    'inflation'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['iran',
#    'nuclear',
#    'deal',
#    'pits',
#    'u',
#    '.',
#    's',
#    '.',
#    'congress',
#    'versus',
#    'u',
#    '.',
#    's',
#    '.',
#    'allies',
#    '?'],
#   'label': 0,
#   'length': 16},
#  {'tokens': ['visit',
#    'home',
#    'reveals',
#    'parents',
#    'currently',
#    'watching',
#    'previously',
#    'undiscovered',
#    'game',
#    'show'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['psychopath',
#    'joins',
#    'fourth',
#    'straight',
#    'republican',
#    'administration'],
#   'label': 1,
#   'length': 6},
#  {'tokens': ['sears',
#    'gold',
#    'card',
#    'holder',
#    'pushing',
#    'weight',
#    'around',
#    'area',
#    'sears'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['friend',
#    'whose',
#    'mom',
#    'just',
#    'died',
#    'allowed',
#    'to',
#    'pick',
#    'pizza',
#    'topping'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['shamed',
#    'and',
#    'abandoned',
#    'the',
#    'fate',
#    'of',
#    'syria',
#    "'",
#    's',
#    'former',
#    'female',
#    'inmates'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['cnn',
#    'anchor',
#    'interviews',
#    'al',
#    'jazeera',
#    'anchor',
#    'who',
#    'interviewed',
#    'libyan',
#    'rebels'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['motorcyclists',
#    'riding',
#    '2-wide',
#    'in',
#    'lane',
#    'right',
#    'next',
#    'to',
#    'you',
#    'probably',
#    'know',
#    'what',
#    'they',
#    "'",
#    're',
#    'doing'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['man',
#    'calls',
#    '911',
#    'when',
#    'he',
#    'runs',
#    'out',
#    'of',
#    'rolling',
#    'papers',
#    ',',
#    'police',
#    'say'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['2',
#    'men',
#    'indicted',
#    'in',
#    'bacon',
#    'vandalism',
#    'at',
#    'islamic',
#    'center'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['oatmeal', 'breakfast', 'bars', 'packed', 'with', 'protein'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['north',
#    'korea',
#    'open',
#    'to',
#    'talks',
#    'with',
#    'u',
#    '.',
#    's',
#    '.',
#    ',',
#    'south',
#    'korea',
#    "'",
#    's',
#    'presidential',
#    'office',
#    'says'],
#   'label': 0,
#   'length': 18},
#  {'tokens': ['afghan',
#    'president',
#    'ashraf',
#    'ghani',
#    'offers',
#    'to',
#    'recognize',
#    'taliban',
#    'as',
#    'legitimate',
#    'political',
#    'group'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['an',
#    'american',
#    'talks',
#    'turkey',
#    'about',
#    'the',
#    "'",
#    'intolerant',
#    "'",
#    'chicken'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['van',
#    'jones',
#    'tough-guy',
#    "'",
#    'trumpzilla',
#    "'",
#    'has',
#    'become',
#    "'",
#    'president',
#    'snowflake',
#    "'"],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['school',
#    'principal',
#    'pauses',
#    'for',
#    'applause',
#    'that',
#    'never',
#    'comes'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['chrissy',
#    'teigen',
#    'wants',
#    'you',
#    'to',
#    'survive',
#    'your',
#    'post-election',
#    'thanksgiving'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['that',
#    'guy',
#    'from',
#    'that',
#    'one',
#    'show',
#    'attempting',
#    'comeback'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['fussy', 'eater', '38'], 'label': 1, 'length': 3},
#  {'tokens': ['area',
#    'ladder',
#    'never',
#    'thought',
#    'it',
#    'would',
#    'end',
#    'up',
#    'a',
#    'bookcase'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['dog', 'befriends', 'roomba'], 'label': 1, 'length': 3},
#  {'tokens': ['hollywood',
#    'executive',
#    'we',
#    'should',
#    'have',
#    'done',
#    'more',
#    'to',
#    'stop',
#    'harvey',
#    'weinstein'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['if',
#    'the',
#    'presidential',
#    'election',
#    'were',
#    'held',
#    'tomorrow',
#    ',',
#    'i',
#    "'",
#    'd',
#    'shoot',
#    'myself'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['will',
#    'forte',
#    "'",
#    's',
#    'gross',
#    'beard',
#    'test',
#    'results',
#    'will',
#    'make',
#    'you',
#    'want',
#    'to',
#    'shave'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['here',
#    "'",
#    's',
#    'what',
#    'happens',
#    'when',
#    'a',
#    'spouse',
#    'who',
#    'identified',
#    'as',
#    'straight',
#    'comes',
#    'out',
#    'as',
#    'lgbt'],
#   'label': 0,
#   'length': 16},
#  {'tokens': ['cooking',
#    'off',
#    'the',
#    'cuff',
#    'italian',
#    'rice',
#    'and',
#    'sausage',
#    '(',
#    'let',
#    "'",
#    's',
#    'not',
#    'call',
#    'it',
#    'risotto',
#    ')'],
#   'label': 0,
#   'length': 17},
#  {'tokens': ['israeli',
#    'forces',
#    'kill',
#    'palestinian',
#    'youth',
#    'wielding',
#    'knife',
#    'at',
#    'checkpoint'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['there',
#    'is',
#    'no',
#    'plan',
#    'b',
#    'either',
#    'in',
#    'yemen',
#    'or',
#    'in',
#    'syria'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['this',
#    'one',
#    'simple',
#    'thing',
#    'makes',
#    'for',
#    'a',
#    'long-lasting',
#    'marriage'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['joe',
#    'wilson',
#    'getting',
#    'bored',
#    'with',
#    'no-longer-covert',
#    'wife'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['father',
#    'of',
#    'parkland',
#    'victim',
#    'creates',
#    'powerful',
#    'mural',
#    'honoring',
#    'son',
#    'and',
#    '16',
#    'others',
#    'killed'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['family',
#    'spends',
#    'relaxing',
#    'weekend',
#    'destroying',
#    'outdoors'],
#   'label': 1,
#   'length': 6},
#  {'tokens': ['game',
#    'review',
#    "'",
#    'super',
#    'mario',
#    'maker',
#    "'",
#    'is',
#    'a',
#    'diy',
#    'triumph'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['donald',
#    'trump',
#    'makes',
#    'dubious',
#    'claim',
#    'about',
#    'inauguration',
#    'singer',
#    'jackie',
#    'evancho'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['study',
#    'more',
#    'couples',
#    'delaying',
#    'divorce',
#    'until',
#    'kids',
#    'old',
#    'enough',
#    'to',
#    'remember',
#    'every',
#    'painful',
#    'detail'],
#   'label': 1,
#   'length': 14},
#  {'tokens': ['all-american',
#    'ticket',
#    'hails',
#    'from',
#    'alaska',
#    ',',
#    'panama',
#    'canal',
#    'zone'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['grateful',
#    'dead',
#    'lyricist',
#    ',',
#    'internet',
#    'pioneer',
#    'john',
#    'perry',
#    'barlow',
#    'dead',
#    'at',
#    '70'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['cat',
#    'prepares',
#    'for',
#    'anal',
#    'display',
#    'in',
#    'owner',
#    "'",
#    's',
#    'face'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['vatican',
#    'declares',
#    'hours',
#    'between',
#    '3',
#    'a',
#    '.',
#    'm',
#    '.',
#    ',',
#    '5',
#    '30',
#    'a',
#    '.',
#    'm',
#    '.',
#    "'",
#    'ungodly',
#    "'"],
#   'label': 1,
#   'length': 19},
#  {'tokens': ['campbell',
#    "'",
#    's',
#    'unveils',
#    'one',
#    'big',
#    'can-sized',
#    'noodle'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['janis',
#    'joplin',
#    "'",
#    'who',
#    'you',
#    'are',
#    'is',
#    'what',
#    'you',
#    'settle',
#    'for',
#    ',',
#    'you',
#    'know',
#    '?',
#    "'"],
#   'label': 0,
#   'length': 16},
#  {'tokens': ['entirety',
#    'of',
#    'hollywood',
#    'film',
#    'industry',
#    'replaced',
#    'with',
#    '40',
#    ',',
#    '000',
#    'christopher',
#    'plummers'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['6', 'essentials', 'for', 'a', 'trash-free', 'lunch'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['peruvian',
#    'shockingly',
#    'knowledgeable',
#    'about',
#    'u',
#    '.',
#    's',
#    '.',
#    'history'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['iraqi',
#    'catholic',
#    'bishop',
#    'still',
#    'has',
#    'vivid',
#    'memories',
#    'of',
#    'mosul',
#    "'",
#    's',
#    'fall'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['horrible',
#    'pack',
#    'of',
#    'theme-restaurant',
#    'waitresses',
#    'alerted',
#    'of',
#    'patron',
#    "'",
#    's',
#    'birthday'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['trump',
#    'planning',
#    'to',
#    'throw',
#    'lie',
#    'about',
#    'immigrant',
#    'crime',
#    'rate',
#    'out',
#    'there',
#    'early',
#    'in',
#    'debate',
#    'to',
#    'gauge',
#    'how',
#    'much',
#    'he',
#    'can',
#    'get',
#    'away',
#    'with'],
#   'label': 1,
#   'length': 23},
#  {'tokens': ['woman',
#    'went',
#    'into',
#    'labor',
#    'on',
#    'beach',
#    'in',
#    'nice',
#    'during',
#    'attack'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['why',
#    'going',
#    'abroad',
#    'isn',
#    "'",
#    't',
#    'always',
#    'rainbows',
#    'and',
#    'butterflies'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['nancy', 'reagan', 'available', 'at', '82'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['heroic',
#    'cancer',
#    'sufferer',
#    'inspires',
#    'others',
#    'to',
#    'get',
#    'cancer'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['a',
#    'global',
#    'meditation',
#    'for',
#    'world',
#    'peace',
#    ',',
#    'december',
#    '12',
#    ',',
#    '2014'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['cheer', 'up', ',', 'democrats'], 'label': 0, 'length': 4},
#  {'tokens': ['at', 'the', 'heart', 'of', 'cop20', 'loss', 'and', 'damage'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['millions',
#    'participate',
#    'in',
#    'cuban',
#    'version',
#    'of',
#    'survivor'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['the', '5', 'best', 'basic', 'phones', 'for', 'kids'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['in',
#    'late-night',
#    'dissent',
#    ',',
#    'justice',
#    'breyer',
#    'sounds',
#    'off',
#    'against',
#    'solitary',
#    'confinement'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['savannah',
#    'guthrie',
#    'will',
#    'stay',
#    'away',
#    'from',
#    'rio',
#    'olympics',
#    'over',
#    'zika',
#    'fears'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['report',
#    'only',
#    '1',
#    'in',
#    '3',
#    'preschool',
#    'graduates',
#    'has',
#    'necessary',
#    'animal',
#    'sound',
#    'skills',
#    'upon',
#    'entering',
#    'zoo'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['report',
#    'limbo',
#    'competition',
#    'nation',
#    "'",
#    's',
#    'last',
#    'example',
#    'of',
#    'pure',
#    'meritocracy'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['the',
#    'sales',
#    'of',
#    'the',
#    'week',
#    'will',
#    'make',
#    'you',
#    'forget',
#    'that',
#    'it',
#    "'",
#    's',
#    '30',
#    'degrees',
#    'in',
#    'april'],
#   'label': 0,
#   'length': 17},
#  {'tokens': ['report',
#    'increasing',
#    'number',
#    'of',
#    'u',
#    '.',
#    's',
#    '.',
#    'toddlers',
#    'attending',
#    'online',
#    'preschool'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['the',
#    'embarrassing',
#    'skin',
#    'problem',
#    'nobody',
#    'talks',
#    'about'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['brave',
#    'beachgoers',
#    'take',
#    'huge',
#    'chance',
#    'to',
#    'rescue',
#    'tiger',
#    'shark'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['words',
#    'of',
#    'wisdom',
#    'gained',
#    'from',
#    'watching',
#    'the',
#    'comey',
#    'hearing'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['queen', 'of', 'soul', 'commands', 'in', 'philly'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['the', 'people', 'paradox'], 'label': 0, 'length': 3},
#  {'tokens': ['in', 'the', 'heights'], 'label': 0, 'length': 3},
#  {'tokens': ['college',
#    'freshman',
#    'decides',
#    'to',
#    'be',
#    'lanyard-wearing',
#    'kind'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['surprise',
#    ',',
#    'surprise',
#    'christopher',
#    'nolan',
#    'is',
#    'not',
#    'a',
#    'fan',
#    'of',
#    'netflix'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['robert',
#    'pattinson',
#    '&',
#    'fka',
#    'twigs',
#    'spend',
#    'time',
#    'at',
#    'chateau',
#    'marmont'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['area',
#    'man',
#    'would',
#    'put',
#    'that',
#    'meeting',
#    'in',
#    'his',
#    'top',
#    '5',
#    'all',
#    'time'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['coroner', 'excited', 'for', 'first', 'asian'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['islamic', 'fundamentalists', 'condemn', 'casual', 'day'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['obama',
#    'explains',
#    'difference',
#    'between',
#    'police',
#    'reform',
#    'and',
#    "'",
#    'war',
#    'on',
#    'cops',
#    "'"],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['npr', 'host', 'raises', 'voice'], 'label': 1, 'length': 4},
#  {'tokens': ['guy', 'with', 'kids', 'to', 'have', 'more', 'kids'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['how',
#    'discriminatory',
#    'immigration',
#    'policy',
#    'affects',
#    'the',
#    'unborn'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['study',
#    'finds',
#    'cats',
#    'only',
#    'meow',
#    'when',
#    'they',
#    'want',
#    'to',
#    'alert',
#    'owner',
#    'of',
#    'neighbor',
#    "'",
#    's',
#    'murder',
#    'they',
#    'witnessed',
#    'through',
#    'window'],
#   'label': 1,
#   'length': 20},
#  {'tokens': ['voters',
#    'are',
#    'excited',
#    'for',
#    'november',
#    'despite',
#    'not',
#    'really',
#    'loving',
#    'the',
#    'likely',
#    'nominees'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['what',
#    "'",
#    's',
#    'it',
#    'like',
#    'waiting',
#    'for',
#    'donald',
#    'trump',
#    'to',
#    'take',
#    'office',
#    '?',
#    'a',
#    'career',
#    'federal',
#    'employee',
#    'spills',
#    'the',
#    'beans'],
#   'label': 0,
#   'length': 20},
#  {'tokens': ['i',
#    "'",
#    'm',
#    'a',
#    'therapist',
#    ',',
#    'and',
#    'sometimes',
#    'i',
#    'get',
#    'deeply',
#    'lonely',
#    '–',
#    'here',
#    "'",
#    's',
#    'how',
#    'i',
#    'deal'],
#   'label': 0,
#   'length': 19},
#  {'tokens': ['director',
#    'for',
#    'aspca',
#    'commercial',
#    'demands',
#    'sadder',
#    'looking',
#    'dogs'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['audubon',
#    'society',
#    'revokes',
#    'black-capped',
#    'chickadee',
#    "'",
#    's',
#    'membership',
#    'after',
#    'species',
#    'fails',
#    'to',
#    'pay',
#    'dues'],
#   'label': 1,
#   'length': 14},
#  {'tokens': ['the',
#    'gulf',
#    'crisis',
#    'fake',
#    'news',
#    'shines',
#    'spotlight',
#    'on',
#    'psychological',
#    'warfare'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['pet',
#    'halloween',
#    'costumes',
#    'are',
#    'the',
#    'spooky',
#    ',',
#    'yet',
#    'cute',
#    'trend',
#    'of',
#    '2015'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['california',
#    "'",
#    's',
#    'brutal',
#    'drought',
#    'could',
#    'change',
#    'the',
#    'state',
#    'forever'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['obama',
#    'leaves',
#    'post-it',
#    'on',
#    'counter',
#    'with',
#    'quick',
#    'note',
#    'explaining',
#    'how',
#    'to',
#    'use',
#    'extralegal',
#    'surveillance',
#    'apparatus'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['most',
#    'long',
#    'island',
#    'politician',
#    'ever',
#    'attacks',
#    'opponent',
#    'for',
#    'not',
#    'loving',
#    'billy',
#    'joel',
#    'enough'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['guy',
#    'wearing',
#    'thumb',
#    'drive',
#    'around',
#    'neck',
#    'wonders',
#    'if',
#    'you',
#    'tried',
#    'hard',
#    'reboot'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['international',
#    'atom',
#    'registry',
#    'allows',
#    'customers',
#    'to',
#    'name',
#    'atom',
#    'after',
#    'loved',
#    'one'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['how',
#    'to',
#    'transform',
#    'your',
#    'relationship',
#    'with',
#    'money',
#    'to',
#    'plan',
#    'for',
#    'the',
#    'future'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['trump',
#    'supporter',
#    'still',
#    'planning',
#    'on',
#    'rioting',
#    'at',
#    'national',
#    'convention',
#    'anyway'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['heirloom',
#    'plasticware',
#    'lovingly',
#    'handed',
#    'down',
#    'to',
#    'next',
#    'hundred',
#    'thousand',
#    'generations'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['systems',
#    'administrator',
#    'would',
#    'so',
#    'fuck',
#    'new',
#    'trainee'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['word',
#    "'",
#    'innovate',
#    "'",
#    'said',
#    '650',
#    ',',
#    '000',
#    'times',
#    'at',
#    'sxsw',
#    'so',
#    'far'],
#   'label': 1,
#   'length': 13},
#  {'tokens': ['construction',
#    'crew',
#    'arguing',
#    'over',
#    'who',
#    'gets',
#    'to',
#    'use',
#    'the',
#    'fun',
#    'tools'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['how',
#    'this',
#    'couple',
#    'lost',
#    'more',
#    'than',
#    '40',
#    'pounds',
#    'each',
#    'in',
#    'five',
#    'months'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['tale',
#    'of',
#    'two',
#    'primaries',
#    'and',
#    'how',
#    'to',
#    'uphold',
#    'majority',
#    'rule'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['report',
#    '750',
#    ',',
#    '000',
#    'americans',
#    'die',
#    'each',
#    'year',
#    'during',
#    'first',
#    'attempt',
#    'to',
#    'get',
#    'back',
#    'in',
#    'shape'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['trump',
#    'comforts',
#    'grieving',
#    'war',
#    'widow',
#    'by',
#    'assuring',
#    'her',
#    'he',
#    'will',
#    'never',
#    'die'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['in',
#    'final',
#    'machiavellian',
#    'masterstoke',
#    ',',
#    'area',
#    'woman',
#    'adds',
#    "'",
#    'no',
#    'gifts',
#    ',',
#    'please',
#    "'",
#    'to',
#    'bottom',
#    'of',
#    'invitation'],
#   'label': 1,
#   'length': 18},
#  {'tokens': ['guard',
#    'gives',
#    'death',
#    'row',
#    'inmate',
#    'every',
#    'chance',
#    'to',
#    'end',
#    'life',
#    'before',
#    'they',
#    'try',
#    'new',
#    'execution',
#    'drug',
#    'on',
#    'him'],
#   'label': 1,
#   'length': 18},
#  {'tokens': ['guard',
#    'in',
#    'video',
#    'game',
#    'under',
#    'strict',
#    'orders',
#    'to',
#    'repeatedly',
#    'pace',
#    'same',
#    'stretch',
#    'of',
#    'hallway'],
#   'label': 1,
#   'length': 14},
#  {'tokens': ['this',
#    '1927',
#    'essay',
#    'proves',
#    'we',
#    "'",
#    've',
#    'always',
#    'worried',
#    'about',
#    'the',
#    'future',
#    'of',
#    'books'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['mother',
#    'comes',
#    'pretty',
#    'close',
#    'to',
#    'using',
#    'word',
#    "'",
#    'streaming',
#    "'",
#    'correctly'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['mother', 'only', 'wants', 'one', 'bite'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['hot',
#    'new',
#    'secretary',
#    'of',
#    'transportation',
#    'to',
#    "'",
#    'shake',
#    'up',
#    "'",
#    'u',
#    '.',
#    's',
#    '.',
#    'highways'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['excited',
#    'cia',
#    'director',
#    'can',
#    "'",
#    't',
#    'wait',
#    'to',
#    'declassify',
#    'last',
#    'night',
#    "'",
#    's',
#    'incredible',
#    'mission',
#    'in',
#    'middle',
#    'east'],
#   'label': 1,
#   'length': 18},
#  {'tokens': ['feds',
#    'give',
#    '$43',
#    'million',
#    'to',
#    'fast',
#    'track',
#    'development',
#    'of',
#    'ebola',
#    'vaccines'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['how', 'to', 'be', 'influenced', 'by', 'real', 'love'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['is', 'the', 'us', 'government', 'cooking', 'the', 'books', '?'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['clinton', 'reelected', 'by', 'wide', 'margin'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['demolishing',
#    'the',
#    '7',
#    'myths',
#    'propping',
#    'up',
#    'fossil',
#    'fuels'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['gwen',
#    'stefani',
#    'says',
#    'her',
#    'divorce',
#    'from',
#    'gavin',
#    'rossdale',
#    'is',
#    "'",
# ...
#    'finds',
#    'staring',
#    'out',
#    'from',
#    'balcony',
#    'with',
#    'best',
#    'friends',
#    'strongest',
#    'indicator',
#    'that',
#    'this',
#    'your',
#    'city',
#    ',',
#    'your',
#    'time'],
#   'label': 1,
#   'length': 19},
#  {'tokens': ['vice',
#    'president',
#    'pence',
#    'pushes',
#    'expansive',
#    'nato',
#    'and',
#    'defense',
#    'of',
#    'european',
#    'micro-states',
#    'does',
#    'president',
#    'trump',
#    'know',
#    '?'],
#   'label': 0,
#   'length': 16},
#  {'tokens': ['americans',
#    'say',
#    '2-to-1',
#    'that',
#    'we',
#    'never',
#    'should',
#    'have',
#    'invaded',
#    'iraq'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['family',
#    "'",
#    's',
#    'euphemism',
#    'for',
#    'genitals',
#    'really',
#    'weird'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['man',
#    'thinks',
#    'people',
#    'care',
#    'enough',
#    'about',
#    'him',
#    'to',
#    'be',
#    'let',
#    'down',
#    'by',
#    'his',
#    'failures'],
#   'label': 1,
#   'length': 14},
#  {'tokens': ['mitch',
#    'mcconnell',
#    'says',
#    'republicans',
#    'have',
#    'the',
#    'votes',
#    'to',
#    'pass',
#    'tax',
#    'bill'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['lyft',
#    'and',
#    'uber',
#    'pull',
#    'out',
#    'of',
#    'austin',
#    ',',
#    'but',
#    'deceptive',
#    'pricing',
#    'is',
#    'here',
#    'to',
#    'stay'],
#   'label': 0,
#   'length': 15},
#  {'tokens': ['history',
#    'buff',
#    'can',
#    'really',
#    'relate',
#    'to',
#    'millard',
#    'fillmore'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['it',
#    "'",
#    's',
#    'time',
#    'to',
#    'get',
#    'serious',
#    'about',
#    'freedom',
#    'of',
#    'religion'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['dog',
#    'missing',
#    'for',
#    'almost',
#    'a',
#    'decade',
#    'reunites',
#    'with',
#    'family',
#    'in',
#    'colorado'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['benghazi',
#    'committee',
#    'chair',
#    'staffer',
#    'fired',
#    'for',
#    'classified',
#    'info',
#    'breach'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['clinton',
#    'receives',
#    '400',
#    ',',
#    '000',
#    'honorary',
#    'degrees',
#    'for',
#    'college',
#    'commencement',
#    'speech'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['mila',
#    'kunis',
#    'sold',
#    'unlicensed',
#    'boyband',
#    't-shirts',
#    'on',
#    'the',
#    'side',
#    'while',
#    'filming',
#    "'",
#    'that',
#    '70s',
#    'show',
#    "'"],
#   'label': 0,
#   'length': 16},
#  {'tokens': ['norman',
#    'lear',
#    ',',
#    'common',
#    ',',
#    'shonda',
#    'rhimes',
#    'to',
#    'explore',
#    'inequality',
#    'in',
#    'epix',
#    'documentary',
#    'series'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['chewing',
#    ',',
#    'and',
#    'choking',
#    ',',
#    'on',
#    'false',
#    '(',
#    'nutritional',
#    ')',
#    'equivalence'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['john',
#    'dowd',
#    'resigns',
#    'as',
#    'trump',
#    "'",
#    's',
#    'lead',
#    'lawyer',
#    'in',
#    'russia',
#    'probe'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['collapsed',
#    'mine',
#    'used',
#    'as',
#    'excuse',
#    'to',
#    'stall',
#    'coal',
#    'extraction'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['newly',
#    'discovered',
#    'journal',
#    'entries',
#    'reveal',
#    'sacagawea',
#    "'",
#    's',
#    'repeated',
#    'attempts',
#    'to',
#    'ditch',
#    'lewis',
#    'and',
#    'clark'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['elizabeth',
#    'warren',
#    'reams',
#    'gop',
#    "'",
#    'the',
#    'system',
#    'is',
#    'rigged',
#    "'",
#    'against',
#    'americans'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['coast',
#    'guard',
#    'going',
#    'to',
#    'let',
#    'stranded',
#    'yacht',
#    'owner',
#    'sweat',
#    'it',
#    'out',
#    'little',
#    'more'],
#   'label': 1,
#   'length': 13},
#  {'tokens': ["'",
#    'whiteness',
#    'history',
#    'month',
#    "'",
#    'stirs',
#    'up',
#    'controversy',
#    'at',
#    'oregon',
#    'college'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['weird', 'black', 'dot', 'actually', 'part', 'of', 'bowl'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['magic-markered',
#    'initials',
#    'fail',
#    'to',
#    'deter',
#    'breakroom',
#    'rice-cake',
#    'thief'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['why',
#    'britain',
#    "'",
#    's',
#    'spy',
#    'chief',
#    'says',
#    'he',
#    'wouldn',
#    "'",
#    't',
#    'hire',
#    'james',
#    'bond'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['report',
#    'peaceful',
#    'transfer',
#    'of',
#    'power',
#    'makes',
#    'last-minute',
#    'push',
#    'to',
#    'become',
#    'most',
#    'pressing',
#    'issue',
#    'of',
#    '2016',
#    'election'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['hero',
#    'teacher',
#    'stops',
#    'high',
#    'school',
#    'shooter',
#    'in',
#    'washington',
#    'state'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['amazing',
#    'medical',
#    'discovery',
#    'to',
#    'add',
#    'years',
#    'of',
#    'fish-oil',
#    'consumption',
#    'to',
#    'man',
#    "'",
#    's',
#    'life'],
#   'label': 1,
#   'length': 14},
#  {'tokens': ['lone', 'man', 'with', 'six-pack', "'", 'partying', "'"],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['matchbox',
#    '20',
#    'singer',
#    'rob',
#    'thomas',
#    'apologizes',
#    'for',
#    'racist',
#    'comments',
#    'made',
#    'in',
#    'australia'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['new', 'lover', 'features', '30', 'percent', 'more', 'cock'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['robert',
#    'redford',
#    'may',
#    'be',
#    'wrong',
#    'when',
#    'he',
#    'said',
#    'retirement',
#    'leads',
#    'to',
#    'death'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['world', 'cup', 'vs', '.', 'planet', 'earth'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['concerned',
#    'text',
#    'from',
#    'mom',
#    '\u200bgleefully',
#    '\u200bmocked',
#    'like',
#    'ramblings',
#    'of',
#    'village',
#    'idiot'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['you', 'should', 'love', 'beyonce', '!'],
#   'label': 0,
#   'length': 5},
#  {'tokens': ['everyone',
#    'giving',
#    'up',
#    'on',
#    'john',
#    'after',
#    'latest',
#    'movie',
#    'recommendation'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['new',
#    'kfc',
#    'employee',
#    'takes',
#    "'",
#    'fry-q',
#    "'",
#    'test',
#    'in',
#    'employee',
#    'manual'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['copycat',
#    'criminals',
#    'continue',
#    'to',
#    'mimic',
#    'liquor',
#    'store',
#    'robbery',
#    'from',
#    '1822'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['man',
#    'waiting',
#    'to',
#    'see',
#    'how',
#    'few',
#    'more',
#    'decades',
#    'of',
#    'racial',
#    'violence',
#    'play',
#    'out',
#    'before',
#    'taking',
#    'action'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['fda',
#    'deems',
#    'genetically',
#    'modified',
#    'salmon',
#    'too',
#    'handsome',
#    'to',
#    'eat'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['man',
#    'prowling',
#    'at',
#    'airport',
#    'gate',
#    'ready',
#    'to',
#    'pounce',
#    'like',
#    'jungle',
#    'cat',
#    'at',
#    'first',
#    'sign',
#    'of',
#    'boarding'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['miley',
#    'cyrus',
#    'probably',
#    'made',
#    'less',
#    'than',
#    'the',
#    "'",
#    'hannah',
#    'montana',
#    "'",
#    'co-stars',
#    'you',
#    'can',
#    "'",
#    't',
#    'even',
#    'name'],
#   'label': 0,
#   'length': 18},
#  {'tokens': ['aunt',
#    'flo',
#    'makes',
#    'all',
#    'the',
#    'visits',
#    'you',
#    'never',
#    'asked',
#    'for',
#    'in',
#    'adorable',
#    'video'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['learn',
#    'new',
#    'habits',
#    'to',
#    'break',
#    'emotional',
#    'eating',
#    'patterns'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['fat', 'guy', 'mistakenly', 'thought', 'of', 'as', 'strong'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['my', 'battle', 'with', 'depression', 'and', 'anxiety'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['sinclair',
#    'takes',
#    'a',
#    'swipe',
#    'at',
#    'cnn',
#    'with',
#    'misleading',
#    "'",
#    'fake',
#    'news',
#    "'",
#    'video'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['trump',
#    'delivers',
#    'anecdote',
#    'about',
#    'small',
#    'business',
#    'owner',
#    'who',
#    'isn',
#    "'",
#    't',
#    'half',
#    'the',
#    'man',
#    'he',
#    'is'],
#   'label': 1,
#   'length': 16},
#  {'tokens': ['man',
#    'thinks',
#    'going',
#    'to',
#    'vegas',
#    'for',
#    'things',
#    'other',
#    'than',
#    'gambling',
#    'somehow',
#    'less',
#    'sad'],
#   'label': 1,
#   'length': 13},
#  {'tokens': ['amplifyd',
#    '.',
#    'com',
#    'challenges',
#    'starbucks',
#    'and',
#    'peet',
#    "'",
#    's',
#    'coffee',
#    'to',
#    'use',
#    'organic',
#    'milk'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['mystery',
#    'freshman',
#    'dominates',
#    'ice',
#    'breakers',
#    ',',
#    'disappears',
#    'into',
#    'night'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['campaign',
#    'adviser',
#    'recommends',
#    'throwing',
#    'old',
#    'blanket',
#    'over',
#    'romney',
#    'for',
#    'debates'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['climate', 'deal', 'text', "'", 'agreed', "'", 'in', 'paris'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['if',
#    'you',
#    'think',
#    'your',
#    'kid',
#    'has',
#    'trouble',
#    'sleeping',
#    ',',
#    'this',
#    'might',
#    'be',
#    'why'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['nasa',
#    'announces',
#    'future',
#    'shuttle',
#    'launches',
#    'will',
#    'be',
#    'sudden',
#    'and',
#    'without',
#    'warning'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['aarp',
#    'blasted',
#    'as',
#    'out',
#    'of',
#    'touch',
#    ',',
#    'past',
#    'its',
#    'prime'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['morgan',
#    'freeman',
#    "'",
#    's',
#    'snapchat',
#    'fail',
#    'is',
#    'hilariously',
#    'perfect'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['chris',
#    'hemsworth',
#    'knows',
#    "'",
#    'what',
#    'love',
#    'is',
#    "'",
#    'now',
#    'that',
#    'he',
#    'has',
#    'kids'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['white', 'sprinter', 'finishes', 'fifth'],
#   'label': 1,
#   'length': 4},
#  {'tokens': ['adam', 'smith', 'vs', '.', 'ayn', 'rand'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['woman',
#    'knew',
#    'ever',
#    'since',
#    'age',
#    '40',
#    'she',
#    'didn',
#    "'",
#    't',
#    'want',
#    'children'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['man',
#    'always',
#    'attempts',
#    'to',
#    'intercept',
#    'tossed',
#    'things'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['mother',
#    'considers',
#    'son',
#    "'",
#    'quite',
#    'the',
#    'little',
#    'casanova',
#    "'"],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['once',
#    'mighty',
#    'super',
#    'bowl',
#    'commercial',
#    'now',
#    'sad',
#    ',',
#    'pathetic',
#    "'",
#    'price',
#    'is',
#    'right',
#    "'",
#    'commercial'],
#   'label': 1,
#   'length': 15},
#  {'tokens': ['carrie',
#    'fisher',
#    'calls',
#    'controversy',
#    'over',
#    'princess',
#    'leia',
#    'bikini',
#    'toys',
#    "'",
#    'stupid',
#    "'"],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['tom',
#    'brokaw',
#    'touched',
#    'so',
#    'many',
#    'women',
#    'would',
#    'go',
#    'out',
#    'of',
#    'their',
#    'way',
#    'to',
#    'defend',
#    'filthy',
#    'old',
#    'pervert',
#    'like',
#    'himself'],
#   'label': 1,
#   'length': 19},
#  {'tokens': ['chipotle',
#    'ceo',
#    'predicts',
#    'the',
#    'demise',
#    'of',
#    "'",
#    'irrelevant',
#    "'",
#    'fast',
#    'food',
#    'chains'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['fire', 'department', 'deploys', 'unmarked', 'trucks'],
#   'label': 1,
#   'length': 5},
#  {'tokens': ['want', 'to', 'be', 'healthier', '?', 'flirt', 'more'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['gop',
#    'operatives',
#    'aren',
#    "'",
#    't',
#    'so',
#    'sure',
#    'that',
#    'trump',
#    'even',
#    'wants',
#    'to',
#    'win'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['u',
#    '.',
#    's',
#    '.',
#    'postal',
#    'service',
#    'appoints',
#    'first',
#    'leather-clad',
#    'postmistress',
#    'general'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ['would',
#    'a',
#    'push',
#    'to',
#    'hire',
#    'more',
#    'women',
#    'reduce',
#    'gender',
#    'pay-gap',
#    '?',
#    'not',
#    'until',
#    'we',
#    'fix',
#    'the',
#    'pipeline'],
#   'label': 0,
#   'length': 17},
#  {'tokens': ['cockroach',
#    'worried',
#    'about',
#    'what',
#    'kind',
#    'of',
#    'kitchen',
#    'cupboard',
#    'he',
#    'leaving',
#    'to',
#    'children'],
#   'label': 1,
#   'length': 12},
#  {'tokens': ['argentina',
#    'president',
#    "'",
#    's',
#    'bizarre',
#    'werewolf',
#    'mishap'],
#   'label': 0,
#   'length': 7},
#  {'tokens': ['burglar',
#    'bursts',
#    'through',
#    'ymca',
#    'ceiling',
#    ',',
#    'steals',
#    'toy',
#    'money'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ['casting',
#    'zionism',
#    'as',
#    "'",
#    'white',
#    'nationalism',
#    "'",
#    'is',
#    'anti-semitism'],
#   'label': 0,
#   'length': 9},
#  {'tokens': ["'",
#    'game',
#    'of',
#    'thrones',
#    "'",
#    'producers',
#    'reveal',
#    'series',
#    'moved',
#    'beyond',
#    'show',
#    "'",
#    's',
#    'written',
#    'script',
#    'halfway',
#    'through',
#    'current',
#    'season'],
#   'label': 1,
#   'length': 19},
#  {'tokens': ['focus',
#    'groups',
#    'and',
#    'instant',
#    'polls',
#    'won',
#    "'",
#    't',
#    'tell',
#    'you',
#    'who',
#    "'",
#    'won',
#    "'",
#    'the',
#    'debate'],
#   'label': 0,
#   'length': 16},
#  {'tokens': ['truther',
#    'jihadist',
#    'wishes',
#    'al-qaeda',
#    'had',
#    'committed',
#    '9/11',
#    'attacks'],
#   'label': 1,
#   'length': 8},
#  {'tokens': ['anti-defamation',
#    'league',
#    'will',
#    'use',
#    'donald',
#    'trump',
#    "'",
#    's',
#    'donations',
#    'to',
#    'fund',
#    'anti-bullying',
#    'programs'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['book', 'review', 'dataclysm'], 'label': 0, 'length': 3},
#  {'tokens': ['watch',
#    'shep',
#    'smith',
#    "'",
#    's',
#    'chilling',
#    'description',
#    'of',
#    'new',
#    'isis',
#    'video'],
#   'label': 0,
#   'length': 11},
#  {'tokens': ['fbi',
#    'agent',
#    "'",
#    's',
#    'cover',
#    'blown',
#    'by',
#    'own',
#    'jacket'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['what',
#    'the',
#    'house',
#    'gop',
#    'isn',
#    "'",
#    't',
#    'telling',
#    'you',
#    'about',
#    'their',
#    'obamacare',
#    'repeal',
#    'bill'],
#   'label': 0,
#   'length': 14},
#  {'tokens': ['this',
#    'is',
#    'what',
#    'it',
#    'was',
#    'like',
#    'to',
#    'go',
#    'to',
#    'the',
#    'airport',
#    'before',
#    '9/11'],
#   'label': 0,
#   'length': 13},
#  {'tokens': ['new',
#    'epa',
#    'chief',
#    'proposes',
#    '30%',
#    'cut',
#    'in',
#    'all',
#    'carbon-based',
#    'organisms'],
#   'label': 1,
#   'length': 10},
#  {'tokens': ['why',
#    'we',
#    'should',
#    'care',
#    'about',
#    'changes',
#    'in',
#    'the',
#    'pharmaceutical',
#    'industry'],
#   'label': 0,
#   'length': 10},
#  {'tokens': ['disappointing',
#    'buffalo',
#    'wild',
#    'wings',
#    'not',
#    'living',
#    'up',
#    'to',
#    'ridicule'],
#   'label': 1,
#   'length': 9},
#  {'tokens': ['clif', 'bar', 'introduces', 'new', 'savory', 'clif', 'loaf'],
#   'label': 1,
#   'length': 7},
#  {'tokens': ['missed', 'connections', 'at', 'a', 'trump', 'rally'],
#   'label': 0,
#   'length': 6},
#  {'tokens': ['video',
#    'shows',
#    'e-cigarette',
#    'suddenly',
#    'explode',
#    'in',
#    'new',
#    'jersey',
#    'woman',
#    "'",
#    's',
#    'handbag'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['this',
#    'site',
#    'lets',
#    'parents',
#    'easily',
#    'show',
#    'their',
#    'kids',
#    'how',
#    'to',
#    'give',
#    'back'],
#   'label': 0,
#   'length': 12},
#  {'tokens': ['local',
#    'oaf',
#    'not',
#    'sure',
#    'what',
#    'part',
#    'of',
#    'counter',
#    'you',
#    'order',
#    'at'],
#   'label': 1,
#   'length': 11},
#  {'tokens': ["'",
#    'snl',
#    "'",
#    'version',
#    'of',
#    'angela',
#    'merkel',
#    'is',
#    'not',
#    'happy',
#    'donald',
#    'trump',
#    'is',
#    'time',
#    "'",
#    's',
#    "'",
#    'person',
#    'of',
#    'the',
#    'year',
#    "'"],
#   'label': 0,
#   'length': 22},
#  {'tokens': ['the', 'portland', 'heroes', 'who', 'stood', 'up', 'to', 'hate'],
#   'label': 0,
#   'length': 8},
#  {'tokens': ['town', 'nervously', 'welcomes', 'veteran', 'back', 'home'],
#   'label': 1,
#   'length': 6},
#  ...]
